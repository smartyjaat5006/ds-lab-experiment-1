# %% [markdown]
# <a href="https://colab.research.google.com/github/smartyjaat5006/ds-lab-experiment-1/blob/main/amitAi10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 50 Pandas Operations Questions — Google Colab Assignment

# %% [markdown]
# ## A. Loading and Exploring the Dataset

# %% [markdown]
# ### Q2. Display the first 5 rows of the dataset.

# %%
csv_files = ["students.csv"]
e = 0
df = pd.read_csv(csv_files[e])

# %%
df.head(5)
# Out:
#   student_id   student_name  gender   age  semester  attendance_percent  \
# 0      DS001   Nisha Pandey    Male  22.0         7                62.0
# 1      DS002  Aarav Chauhan  Female  23.0         7                74.4
# 2      DS003   Aditya Gupta  Female  20.0         7                75.3
# 3      DS004   Aditya Kumar    Male  21.0         4                84.8
# 4      DS005    Neha Pandey  Female  23.0         6                57.0
#
#                   study_hours_per_day  assignment_average  quiz_average  \
# 0                 1.8            48.2                92.0          74.1
# 1  2.5            78.7           48.4                 NaN          54.0
# 2  1.1            96.8           73.8                 NaN          60.1
# 3  2.6            73.6           72.8                 NaN          47.0
# 4  2.6            66.4           56.3                 NaN          88.9
#
#    mid_sem_score  ...  lab_hours_per_week  online_activity_count  \
# ...

# %% [markdown]
# ### Q3. Display the last 10 rows of the dataset.

# %%
df.tail(10)
# Out:
#     student_id    student_name  gender   age  semester  attendance_percent  \
# 190      DS191    Riya Chauhan    Male  22.0         4                87.2
# 191      DS192      Isha Sinha    Male  20.0         4                69.1
# 192      DS193  Saurabh Mishra    Male  22.0         7                94.4
# 193      DS194     Rohan Yadav    Male  21.0         3                76.4
# 194      DS195     Rahul Yadav    Male  23.0         3                90.8
# 195      DS196     Aarav Verma  Female  22.0         6                56.9
# 196      DS197   Arjun Chauhan    Male  20.0         3                88.1
# 197      DS198      Neha Kumar  Female  21.0         4                93.6
# 198      DS199     Priya Gupta    Male  21.0         7                98.8
# 199      DS200    Vivaan Singh    Male  21.0         7                88.6
#
#     study_hours_per_day  assignment_average  quiz_average  mid_sem_score  ...  \
# ...

# %% [markdown]
# ### Q4. Find the number of rows and columns in the DataFrame.

# %%
print("Rows:", df.shape[0])
print("Columns:", df.shape[1])
# Out:
# Rows: 200
# Columns: 21

# %% [markdown]
# ### Q5. Display all column names.

# %%
print(df.columns.tolist())
# Out:
# ['student_id', 'student_name', 'gender', 'age', 'semester', 'attendance_percent', 'study_hours_per_day', 'assignment_average', 'quiz_average', 'mid_sem_score', 'previous_cgpa', 'lab_hours_per_week', 'online_activity_count', 'projects_completed', 'python_skill_level', 'mathematics_skill', 'engagement_score', 'predicted_score', 'grade', 'risk_level', 'learning_recommendation']

# %% [markdown]
# ### Q6. Display the data type of every column.

# %%
print(df.dtypes)
# Out:
# student_id                  object
# student_name                object
# gender                      object
# age                        float64
# semester                     int64
# attendance_percent         float64
# study_hours_per_day         object
# assignment_average         float64
# quiz_average               float64
# mid_sem_score              float64
# previous_cgpa              float64
# lab_hours_per_week         float64
# online_activity_count        int64
# projects_completed           int64
# python_skill_level          object
# mathematics_skill           object
# engagement_score           float64
# predicted_score            float64
# grade                       object
# risk_level                  object
# learning_recommendation     object
# dtype: object

# %% [markdown]
# ### Q7. Use df.info() to display a concise summary of the dataset.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 21 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   student_id               200 non-null    object
#  1   student_name             200 non-null    object
#  2   gender                   200 non-null    object
#  3   age                      198 non-null    float64
#  4   semester                 200 non-null    int64
#  5   attendance_percent       200 non-null    float64
#  6   study_hours_per_day      200 non-null    object
#  7   assignment_average       159 non-null    float64
#  8   quiz_average             200 non-null    float64
#  9   mid_sem_score            199 non-null    float64
#  10  previous_cgpa            156 non-null    float64
#  11  lab_hours_per_week       199 non-null    float64
#  12  online_activity_count    200 non-null    int64
#  13  projects_completed       200 non-null    int64
# ...

# %% [markdown]
# ### Q8. Generate descriptive statistics for all numerical columns.

# %%
df.describe()
# Out:
#               age    semester  attendance_percent  assignment_average  \
# count  198.000000  200.000000          200.000000          159.000000
# mean    20.590909    5.580000           77.457500           73.310692
# std      1.744991    1.657509           12.294528           16.657015
# min     18.000000    3.000000           55.000000           45.000000
# 25%     19.000000    4.000000           67.150000           59.250000
# 50%     21.000000    6.000000           77.950000           74.200000
# 75%     22.000000    7.000000           88.500000           89.400000
# max     23.000000    8.000000           99.800000           99.800000
#
#        quiz_average  mid_sem_score  previous_cgpa  lab_hours_per_week  \
# count    200.000000     199.000000     156.000000          199.000000
# mean      69.270000      52.769146       7.369615            3.973367
# std       18.017789      29.266812       1.427444            2.184413
# ...

# %% [markdown]
# ### Q9. Check whether the dataset contains any missing values.

# %%
print(df.isnull().sum())
print("\nAny missing values:", df.isnull().values.any())
# Out:
# student_id                  0
# student_name                0
# gender                      0
# age                         2
# semester                    0
# attendance_percent          0
# study_hours_per_day         0
# assignment_average         41
# quiz_average                0
# mid_sem_score               1
# previous_cgpa              44
# lab_hours_per_week          1
# online_activity_count       0
# projects_completed          0
# python_skill_level          0
# mathematics_skill           9
# engagement_score            0
# predicted_score             0
# grade                       0
# risk_level                  0
# learning_recommendation     0
# dtype: int64
#
# Any missing values: True

# %% [markdown]
# ### Q10. Find the number of unique values in each column.

# %%
print(df.nunique())
# Out:
# student_id                 200
# student_name               123
# gender                       2
# age                          6
# semester                     6
# attendance_percent         166
# study_hours_per_day         94
# assignment_average         137
# quiz_average               176
# mid_sem_score              177
# previous_cgpa              137
# lab_hours_per_week          75
# online_activity_count      130
# projects_completed           6
# python_skill_level           3
# mathematics_skill            3
# engagement_score           170
# predicted_score            146
# grade                        4
# risk_level                   3
# learning_recommendation      4
# dtype: int64

# %% [markdown]
# ## B. Selecting and Accessing Data

# %% [markdown]
# ### Q11. Select and display only the student_name, gender, and semester columns.

# %%
df[["student_name", "gender", "semester"]]
# Out:
#       student_name  gender  semester
# 0     Nisha Pandey    Male         7
# 1    Aarav Chauhan  Female         7
# 2     Aditya Gupta  Female         7
# 3     Aditya Kumar    Male         4
# 4      Neha Pandey  Female         6
# ..             ...     ...       ...
# 195    Aarav Verma  Female         6
# 196  Arjun Chauhan    Male         3
# 197     Neha Kumar  Female         4
# 198    Priya Gupta    Male         7
# 199   Vivaan Singh    Male         7
#
# [200 rows x 3 columns]

# %% [markdown]
# ### Q12. Display all students who are in Semester 3.

# %%
df[df["semester"] == 3]
# Out:
#     student_id    student_name  gender   age  semester  attendance_percent  \
# 17       DS018    Arjun Sharma    Male  18.0         3                99.8
# 18       DS019    Aarav Sharma  Female   NaN         3                72.8
# 31       DS032    Ananya Singh    Male  21.0         3                89.3
# 38       DS039      Riya Kumar  Female  19.0         3                73.7
# 39       DS040      Riya Gupta    Male  23.0         3                60.8
# 44       DS045     Rahul Kumar    Male  22.0         3                71.0
# 60       DS061   Kunal Chauhan    Male  21.0         3                55.2
# 64       DS065   Simran Mishra    Male  22.0         3                79.8
# 77       DS078      Riya Gupta    Male  21.0         3                81.1
# 94       DS095     Aryan Singh  Female  21.0         3                78.3
# 95       DS096  Saurabh Mishra  Female  21.0         3                97.8
# ...

# %% [markdown]
# ### Q13. Display all female students.

# %%
df[df["gender"].str.lower() == "female"]
# Out:
#     student_id    student_name  gender   age  semester  attendance_percent  \
# 1        DS002   Aarav Chauhan  Female  23.0         7                74.4
# 2        DS003    Aditya Gupta  Female  20.0         7                75.3
# 4        DS005     Neha Pandey  Female  23.0         6                57.0
# 6        DS007    Aarav Mishra  Female  23.0         7                87.8
# 7        DS008    Sneha Sharma  Female  18.0         6                80.3
# ..         ...             ...     ...   ...       ...                 ...
# 184      DS185     Pooja Singh  Female  18.0         5                64.5
# 187      DS188  Vivaan Chauhan  Female  22.0         6                93.9
# 189      DS190      Neha Yadav  Female  23.0         6                61.4
# 195      DS196     Aarav Verma  Female  22.0         6                56.9
# 197      DS198      Neha Kumar  Female  21.0         4                93.6
#
# ...

# %% [markdown]
# ### Q14. Find students whose previous_cgpa is greater than 8.0.

# %%
df[df["previous_cgpa"] > 8.0]
# Out:
#     student_id    student_name  gender   age  semester  attendance_percent  \
# 49       DS050    Kunal Mishra  Female  20.0         5                55.8
# 50       DS051   Vivaan Pandey  Female  19.0         5                92.7
# 52       DS053   Ananya Pandey    Male  23.0         5                70.7
# 53       DS054     Aryan Sinha  Female  22.0         8                91.0
# 56       DS057   Rohan Chauhan  Female  18.0         8                92.0
# 58       DS059    Simran Sinha  Female  18.0         6                81.7
# 59       DS060     Aryan Sinha  Female  23.0         5                75.3
# 69       DS070    Rahul Pandey    Male  19.0         6                83.5
# 73       DS074     Neha Pandey    Male  20.0         7                89.2
# 78       DS079     Arjun Singh  Female  23.0         7                56.9
# 79       DS080    Kavya Pandey    Male  20.0         8                82.6
# ...

# %% [markdown]
# ### Q15. Display students whose attendance_percent is below 75%.

# %%
df[df["attendance_percent"] < 75]
# Out:
#     student_id   student_name  gender   age  semester  attendance_percent  \
# 0        DS001   Nisha Pandey    Male  22.0         7                62.0
# 1        DS002  Aarav Chauhan  Female  23.0         7                74.4
# 4        DS005    Neha Pandey  Female  23.0         6                57.0
# 5        DS006     Aman Sinha    Male  18.0         6                68.2
# 10       DS011   Nisha Mishra  Female  19.0         5                68.5
# ..         ...            ...     ...   ...       ...                 ...
# 182      DS183     Isha Gupta    Male  23.0         5                73.3
# 184      DS185    Pooja Singh  Female  18.0         5                64.5
# 189      DS190     Neha Yadav  Female  23.0         6                61.4
# 191      DS192     Isha Sinha    Male  20.0         4                69.1
# 195      DS196    Aarav Verma  Female  22.0         6                56.9
#
#                     study_hours_per_day  assignment_average  quiz_average  \
# ...

# %% [markdown]
# ### Q16. Find students who study more than 4 hours per day.

# %%
df["study_hours_per_day"] = pd.to_numeric(df["study_hours_per_day"], errors="coerce")
df[df["study_hours_per_day"] > 4]
# Out:
#     student_id   student_name  gender   age  semester  attendance_percent  \
# 47       DS048    Priya Sinha  Female  18.0         7                81.7
# 49       DS050   Kunal Mishra  Female  20.0         5                55.8
# 52       DS053  Ananya Pandey    Male  23.0         5                70.7
# 53       DS054    Aryan Sinha  Female  22.0         8                91.0
# 55       DS056    Aman Sharma    Male  19.0         6                90.7
# 61       DS062     Isha Yadav  Female  18.0         6                73.9
# 65       DS066   Kavya Pandey    Male  23.0         5                98.3
# 67       DS068   Priya Pandey  Female  18.0         4                80.5
# 71       DS072    Arjun Verma  Female  20.0         5                92.9
# 73       DS074    Neha Pandey    Male  20.0         7                89.2
# 80       DS081   Riya Chauhan    Male  20.0         8                91.0
# 83       DS084     Riya Singh    Male  22.0         8                81.7
# ...

# %% [markdown]
# ### Q17. Display students with python_skill_level equal to 'Advanced'.

# %%
df[df["python_skill_level"].str.lower() == "advanced"]
# Out:
#     student_id    student_name  gender   age  semester  attendance_percent  \
# 0        DS001    Nisha Pandey    Male  22.0         7                62.0
# 3        DS004    Aditya Kumar    Male  21.0         4                84.8
# 5        DS006      Aman Sinha    Male  18.0         6                68.2
# 12       DS013    Aditya Verma  Female  21.0         5                64.9
# 13       DS014   Simran Mishra    Male  23.0         4                66.6
# 14       DS015    Kunal Sharma    Male  20.0         5                93.5
# 25       DS026   Nisha Chauhan  Female  19.0         5                77.6
# 36       DS037   Aryan Chauhan  Female  21.0         4                67.0
# 41       DS042    Vivaan Yadav  Female  19.0         4                83.6
# 46       DS047   Aditya Mishra    Male  23.0         5                78.9
# 48       DS049     Rahul Verma    Male  19.0         4                66.0
# ...

# %% [markdown]
# ### Q18. Display all students who obtained grade 'A'.

# %%
df[df["grade"].str.upper() == "A"]
# Out:
#     student_id    student_name  gender   age  semester  attendance_percent  \
# 14       DS015    Kunal Sharma    Male  20.0         5                93.5
# 16       DS017      Isha Yadav  Female  23.0         8                81.5
# 17       DS018    Arjun Sharma    Male  18.0         3                99.8
# 19       DS020     Aarav Sinha  Female  20.0         8                71.2
# 28       DS029   Saurabh Gupta  Female  18.0         5                99.6
# 35       DS036      Neha Kumar  Female  22.0         8                81.3
# 49       DS050    Kunal Mishra  Female  20.0         5                55.8
# 52       DS053   Ananya Pandey    Male  23.0         5                70.7
# 53       DS054     Aryan Sinha  Female  22.0         8                91.0
# 55       DS056     Aman Sharma    Male  19.0         6                90.7
# 69       DS070    Rahul Pandey    Male  19.0         6                83.5
# ...

# %% [markdown]
# ### Q19. Find students whose risk_level is 'High'.

# %%
df[df["risk_level"].str.lower() == "high"]
# Out:
#     student_id   student_name  gender   age  semester  attendance_percent  \
# 0        DS001   Nisha Pandey    Male  22.0         7                62.0
# 4        DS005    Neha Pandey  Female  23.0         6                57.0
# 12       DS013   Aditya Verma  Female  21.0         5                64.9
# 20       DS021   Kavya Sharma  Female  21.0         4                59.2
# 33       DS034   Aditya Singh  Female  21.0         8                57.5
# 37       DS038     Isha Gupta  Female  18.0         4                58.7
# 39       DS040     Riya Gupta    Male  23.0         3                60.8
# 45       DS046    Arjun Kumar    Male  18.0         5                63.3
# 49       DS050   Kunal Mishra  Female  20.0         5                55.8
# 60       DS061  Kunal Chauhan    Male  21.0         3                55.2
# 72       DS073  Saurabh Sinha  Female  20.0         5                58.5
# 78       DS079    Arjun Singh  Female  23.0         7                56.9
# ...

# %% [markdown]
# ### Q20. Display the student_name and predicted_score for students with predicted_score greater than 80.

# %%
df.loc[df["predicted_score"] > 80, ["student_name", "predicted_score"]]
# Out:
#       student_name  predicted_score
# 3     Aditya Kumar             80.1
# 6     Aarav Mishra             83.6
# 11    Rahul Mishra             81.2
# 12    Aditya Verma             82.2
# 14    Kunal Sharma             95.9
# ..             ...              ...
# 190   Riya Chauhan             83.6
# 191     Isha Sinha             87.6
# 196  Arjun Chauhan             86.8
# 198    Priya Gupta             92.6
# 199   Vivaan Singh             89.3
#
# [81 rows x 2 columns]

# %% [markdown]
# ## C. Filtering with Multiple Conditions

# %% [markdown]
# ### Q21. Find students in Semester 4 with attendance_percent greater than 80%.

# %%
df[(df["semester"] == 4) & (df["attendance_percent"] > 80)]
# Out:
#     student_id    student_name  gender   age  semester  attendance_percent  \
# 3        DS004    Aditya Kumar    Male  21.0         4                84.8
# 27       DS028    Riya Chauhan    Male  22.0         4                85.7
# 41       DS042    Vivaan Yadav  Female  19.0         4                83.6
# 42       DS043  Saurabh Pandey  Female  18.0         4                89.6
# 67       DS068    Priya Pandey  Female  18.0         4                80.5
# 76       DS077    Simran Kumar    Male  22.0         4                94.4
# 99       DS100    Vivaan Verma  Female  19.0         4                90.7
# 106      DS107    Simran Singh  Female  18.0         4                94.1
# 118      DS119    Aditya Yadav  Female  23.0         4                99.7
# 123      DS124    Simran Verma    Male  19.0         4                92.0
# 141      DS142     Nisha Verma  Female  23.0         4                82.0
# ...

# %% [markdown]
# ### Q22. Find students whose previous_cgpa is greater than 8.0 and predicted_score is greater than 75.

# %%
df[(df["previous_cgpa"] > 8.0) & (df["predicted_score"] > 75)]
# Out:
#     student_id    student_name  gender   age  semester  attendance_percent  \
# 49       DS050    Kunal Mishra  Female  20.0         5                55.8
# 50       DS051   Vivaan Pandey  Female  19.0         5                92.7
# 52       DS053   Ananya Pandey    Male  23.0         5                70.7
# 53       DS054     Aryan Sinha  Female  22.0         8                91.0
# 56       DS057   Rohan Chauhan  Female  18.0         8                92.0
# 58       DS059    Simran Sinha  Female  18.0         6                81.7
# 59       DS060     Aryan Sinha  Female  23.0         5                75.3
# 69       DS070    Rahul Pandey    Male  19.0         6                83.5
# 73       DS074     Neha Pandey    Male  20.0         7                89.2
# 79       DS080    Kavya Pandey    Male  20.0         8                82.6
# 86       DS087    Rahul Sharma  Female  23.0         4                74.5
# ...

# %% [markdown]
# ### Q23. Find students who are either in Semester 2 or Semester 4.

# %%
df[df["semester"].isin([2, 4])]
# Out:
#     student_id    student_name  gender   age  semester  attendance_percent  \
# 3        DS004    Aditya Kumar    Male  21.0         4                84.8
# 13       DS014   Simran Mishra    Male  23.0         4                66.6
# 20       DS021    Kavya Sharma  Female  21.0         4                59.2
# 27       DS028    Riya Chauhan    Male  22.0         4                85.7
# 36       DS037   Aryan Chauhan  Female  21.0         4                67.0
# 37       DS038      Isha Gupta  Female  18.0         4                58.7
# 41       DS042    Vivaan Yadav  Female  19.0         4                83.6
# 42       DS043  Saurabh Pandey  Female  18.0         4                89.6
# 48       DS049     Rahul Verma    Male  19.0         4                66.0
# 67       DS068    Priya Pandey  Female  18.0         4                80.5
# 76       DS077    Simran Kumar    Male  22.0         4                94.4
# ...

# %% [markdown]
# ### Q24. Find students whose gender is Female and python_skill_level is Advanced.

# %%
df[(df["gender"].str.lower() == "female") & (df["python_skill_level"].str.lower() == "advanced")]
# Out:
#     student_id    student_name  gender   age  semester  attendance_percent  \
# 12       DS013    Aditya Verma  Female  21.0         5                64.9
# 25       DS026   Nisha Chauhan  Female  19.0         5                77.6
# 36       DS037   Aryan Chauhan  Female  21.0         4                67.0
# 41       DS042    Vivaan Yadav  Female  19.0         4                83.6
# 66       DS067    Simran Singh  Female  18.0         7                70.4
# 107      DS108    Vivaan Singh  Female  23.0         3                94.0
# 111      DS112      Neha Sinha  Female  21.0         5                72.1
# 126      DS127    Kavya Sharma  Female  21.0         3                77.9
# 129      DS130     Arjun Singh  Female  21.0         6                84.3
# 134      DS135  Vivaan Chauhan  Female  18.0         4                65.1
# 137      DS138     Isha Mishra  Female  22.0         8                94.3
# ...

# %% [markdown]
# ### Q25. Find students whose study_hours_per_day is between 2 and 5 hours.

# %%
df[df["study_hours_per_day"].between(2, 5)]
# Out:
#     student_id   student_name  gender   age  semester  attendance_percent  \
# 45       DS046    Arjun Kumar    Male  18.0         5                63.3
# 47       DS048    Priya Sinha  Female  18.0         7                81.7
# 48       DS049    Rahul Verma    Male  19.0         4                66.0
# 49       DS050   Kunal Mishra  Female  20.0         5                55.8
# 50       DS051  Vivaan Pandey  Female  19.0         5                92.7
# ..         ...            ...     ...   ...       ...                 ...
# 194      DS195    Rahul Yadav    Male  23.0         3                90.8
# 195      DS196    Aarav Verma  Female  22.0         6                56.9
# 196      DS197  Arjun Chauhan    Male  20.0         3                88.1
# 197      DS198     Neha Kumar  Female  21.0         4                93.6
# 199      DS200   Vivaan Singh    Male  21.0         7                88.6
#
#      study_hours_per_day  assignment_average  quiz_average  mid_sem_score  \
# ...

# %% [markdown]
# ### Q26. Find students whose grade is either A or B.

# %%
df[df["grade"].str.upper().isin(["A", "B"])]
# Out:
#     student_id   student_name  gender   age  semester  attendance_percent  \
# 0        DS001   Nisha Pandey    Male  22.0         7                62.0
# 3        DS004   Aditya Kumar    Male  21.0         4                84.8
# 6        DS007   Aarav Mishra  Female  23.0         7                87.8
# 7        DS008   Sneha Sharma  Female  18.0         6                80.3
# 11       DS012   Rahul Mishra  Female  21.0         5                71.6
# ..         ...            ...     ...   ...       ...                 ...
# 194      DS195    Rahul Yadav    Male  23.0         3                90.8
# 195      DS196    Aarav Verma  Female  22.0         6                56.9
# 196      DS197  Arjun Chauhan    Male  20.0         3                88.1
# 198      DS199    Priya Gupta    Male  21.0         7                98.8
# 199      DS200   Vivaan Singh    Male  21.0         7                88.6
#
#      study_hours_per_day  assignment_average  quiz_average  mid_sem_score  \
# ...

# %% [markdown]
# ### Q27. Find students whose risk_level is either Medium or High.

# %%
df[df["risk_level"].str.lower().isin(["medium", "high"])]
# Out:
#     student_id    student_name  gender   age  semester  attendance_percent  \
# 0        DS001    Nisha Pandey    Male  22.0         7                62.0
# 1        DS002   Aarav Chauhan  Female  23.0         7                74.4
# 4        DS005     Neha Pandey  Female  23.0         6                57.0
# 5        DS006      Aman Sinha    Male  18.0         6                68.2
# 10       DS011    Nisha Mishra  Female  19.0         5                68.5
# ..         ...             ...     ...   ...       ...                 ...
# 184      DS185     Pooja Singh  Female  18.0         5                64.5
# 187      DS188  Vivaan Chauhan  Female  22.0         6                93.9
# 189      DS190      Neha Yadav  Female  23.0         6                61.4
# 191      DS192      Isha Sinha    Male  20.0         4                69.1
# 195      DS196     Aarav Verma  Female  22.0         6                56.9
#
# ...

# %% [markdown]
# ### Q28. Find students with mathematics_skill equal to 'Good' or 'Excellent'.

# %%
df[df["mathematics_skill"].str.lower().isin(["good", "excellent"])]
# Out:
# Empty DataFrame
# Columns: [student_id, student_name, gender, age, semester, attendance_percent, study_hours_per_day, assignment_average, quiz_average, mid_sem_score, previous_cgpa, lab_hours_per_week, online_activity_count, projects_completed, python_skill_level, mathematics_skill, engagement_score, predicted_score, grade, risk_level, learning_recommendation]
# Index: []
#
# [0 rows x 21 columns]

# %% [markdown]
# ### Q29. Find students who completed at least 2 projects and have an engagement_score above 70.

# %%
df[(df["projects_completed"] >= 2) & (df["engagement_score"] > 70)]
# Out:
#     student_id   student_name  gender   age  semester  attendance_percent  \
# 15       DS016    Kavya Singh  Female  19.0         8                75.2
# 18       DS019   Aarav Sharma  Female   NaN         3                72.8
# 21       DS022   Ananya Gupta  Female  18.0         7                67.2
# 25       DS026  Nisha Chauhan  Female  19.0         5                77.6
# 32       DS033    Aryan Kumar    Male  23.0         6                65.7
# 35       DS036     Neha Kumar  Female  22.0         8                81.3
# 37       DS038     Isha Gupta  Female  18.0         4                58.7
# 61       DS062     Isha Yadav  Female  18.0         6                73.9
# 65       DS066   Kavya Pandey    Male  23.0         5                98.3
# 83       DS084     Riya Singh    Male  22.0         8                81.7
# 104      DS105    Nisha Gupta  Female  19.0         5                55.2
# 107      DS108   Vivaan Singh  Female  23.0         3                94.0
# ...

# %% [markdown]
# ### Q30. Find students with attendance_percent above 85%, study_hours_per_day above 3, and grade A.

# %%
df[(df["attendance_percent"] > 85) &
   (df["study_hours_per_day"] > 3) &
   (df["grade"].str.upper() == "A")]
# Out:
#     student_id  student_name  gender   age  semester  attendance_percent  \
# 53       DS054   Aryan Sinha  Female  22.0         8                91.0
# 55       DS056   Aman Sharma    Male  19.0         6                90.7
# 71       DS072   Arjun Verma  Female  20.0         5                92.9
# 73       DS074   Neha Pandey    Male  20.0         7                89.2
# 105      DS106   Nisha Singh    Male  19.0         6                85.3
# 106      DS107  Simran Singh  Female  18.0         4                94.1
# 133      DS134    Riya Verma    Male  23.0         6                89.9
# 198      DS199   Priya Gupta    Male  21.0         7                98.8
# 199      DS200  Vivaan Singh    Male  21.0         7                88.6
#
#      study_hours_per_day  assignment_average  quiz_average  mid_sem_score  \
# 53                   5.1                55.3          54.1           76.2
# 55                   4.1                74.3          93.6           86.3
# ...

# %% [markdown]
# ## D. Sorting and Ranking

# %% [markdown]
# ### Q31. Sort the DataFrame by predicted_score in descending order.

# %%
df.sort_values(by="predicted_score", ascending=False)
# Out:
#     student_id   student_name  gender   age  semester  attendance_percent  \
# 73       DS074    Neha Pandey    Male  20.0         7                89.2
# 14       DS015   Kunal Sharma    Male  20.0         5                93.5
# 122      DS123  Saurabh Kumar  Female  19.0         8                91.8
# 49       DS050   Kunal Mishra  Female  20.0         5                55.8
# 129      DS130    Arjun Singh  Female  21.0         6                84.3
# ..         ...            ...     ...   ...       ...                 ...
# 72       DS073  Saurabh Sinha  Female  20.0         5                58.5
# 167      DS168    Sneha Kumar    Male  20.0         8                82.5
# 162      DS163     Isha Verma    Male  23.0         8                60.4
# 145      DS146     Aman Singh    Male  20.0         3                90.1
# 94       DS095    Aryan Singh  Female  21.0         3                78.3
#
#      study_hours_per_day  assignment_average  quiz_average  mid_sem_score  \
# ...

# %% [markdown]
# ### Q32. Display the top 10 students according to predicted_score.

# %%
df.sort_values(by="predicted_score", ascending=False).head(10)
# Out:
#     student_id   student_name  gender   age  semester  attendance_percent  \
# 73       DS074    Neha Pandey    Male  20.0         7                89.2
# 14       DS015   Kunal Sharma    Male  20.0         5                93.5
# 122      DS123  Saurabh Kumar  Female  19.0         8                91.8
# 49       DS050   Kunal Mishra  Female  20.0         5                55.8
# 129      DS130    Arjun Singh  Female  21.0         6                84.3
# 198      DS199    Priya Gupta    Male  21.0         7                98.8
# 179      DS180     Neha Singh    Male  20.0         6                73.1
# 17       DS018   Arjun Sharma    Male  18.0         3                99.8
# 119      DS120  Pooja Chauhan    Male  23.0         8                75.3
# 19       DS020    Aarav Sinha  Female  20.0         8                71.2
#
#      study_hours_per_day  assignment_average  quiz_average  mid_sem_score  \
# 73                   4.6                80.0          98.8          93.70
# ...

# %% [markdown]
# ### Q33. Display the bottom 10 students according to predicted_score.

# %%
df.sort_values(by="predicted_score", ascending=True).head(10)
# Out:
#     student_id    student_name  gender   age  semester  attendance_percent  \
# 94       DS095     Aryan Singh  Female  21.0         3                78.3
# 145      DS146      Aman Singh    Male  20.0         3                90.1
# 162      DS163      Isha Verma    Male  23.0         8                60.4
# 167      DS168     Sneha Kumar    Male  20.0         8                82.5
# 72       DS073   Saurabh Sinha  Female  20.0         5                58.5
# 160      DS161      Isha Kumar  Female  23.0         5                55.0
# 36       DS037   Aryan Chauhan  Female  21.0         4                67.0
# 187      DS188  Vivaan Chauhan  Female  22.0         6                93.9
# 10       DS011    Nisha Mishra  Female  19.0         5                68.5
# 174      DS175     Arjun Kumar  Female  19.0         6                74.4
#
#      study_hours_per_day  assignment_average  quiz_average  mid_sem_score  \
# ...

# %% [markdown]
# ### Q34. Find the student with the highest predicted_score.

# %%
df.loc[df["predicted_score"].idxmax()]
# Out:
# student_id                             DS074
# student_name                     Neha Pandey
# gender                                  Male
# age                                     20.0
# semester                                   7
# attendance_percent                      89.2
# study_hours_per_day                      4.6
# assignment_average                      80.0
# quiz_average                            98.8
# mid_sem_score                           93.7
# previous_cgpa                            8.1
# lab_hours_per_week                       5.5
# online_activity_count                    118
# projects_completed                         1
# python_skill_level                  Beginner
# mathematics_skill                     Medium
# engagement_score                        68.5
# predicted_score                         96.3
# grade                                      A
# risk_level                               Low
# learning_recommendation    Advanced Projects
# ...

# %% [markdown]
# ### Q35. Find the student with the lowest predicted_score.

# %%
df.loc[df["predicted_score"].idxmin()]
# Out:
# student_id                                        DS095
# student_name                                Aryan Singh
# gender                                           Female
# age                                                21.0
# semester                                              3
# attendance_percent                                 78.3
# study_hours_per_day                                 1.4
# assignment_average                                 64.3
# quiz_average                                       42.0
# mid_sem_score                                      40.1
# previous_cgpa                                      6.91
# lab_hours_per_week                                  1.1
# online_activity_count                               112
# projects_completed                                    1
# python_skill_level                         Intermediate
# mathematics_skill                                  High
# engagement_score                                   39.7
# ...

# %% [markdown]
# ### Q36. Sort students by previous_cgpa in descending order.

# %%
df.sort_values(by="previous_cgpa", ascending=False)
# Out:
#     student_id  student_name  gender   age  semester  attendance_percent  \
# 142      DS143    Isha Verma  Female  23.0         3                74.5
# 139      DS140   Kavya Sinha    Male  19.0         7                71.6
# 93       DS094  Ananya Sinha  Female  18.0         6                90.1
# 90       DS091   Rahul Singh    Male  22.0         5                56.4
# 178      DS179   Isha Sharma    Male  19.0         4                66.7
# ..         ...           ...     ...   ...       ...                 ...
# 39       DS040    Riya Gupta    Male  23.0         3                60.8
# 40       DS041  Simran Kumar    Male  23.0         6                80.2
# 41       DS042  Vivaan Yadav  Female  19.0         4                83.6
# 43       DS044  Pooja Pandey    Male  21.0         6                70.6
# 44       DS045   Rahul Kumar    Male  22.0         3                71.0
#
#      study_hours_per_day  assignment_average  quiz_average  mid_sem_score  \
# ...

# %% [markdown]
# ### Q37. Sort students first by semester and then by predicted_score in descending order.

# %%
df.sort_values(by=["semester", "predicted_score"], ascending=[True, False])
# Out:
#     student_id    student_name  gender   age  semester  attendance_percent  \
# 17       DS018    Arjun Sharma    Male  18.0         3                99.8
# 126      DS127    Kavya Sharma  Female  21.0         3                77.9
# 135      DS136      Aman Kumar    Male  21.0         3                79.5
# 196      DS197   Arjun Chauhan    Male  20.0         3                88.1
# 188      DS189      Isha Gupta    Male  20.0         3                89.2
# ..         ...             ...     ...   ...       ...                 ...
# 92       DS093     Pooja Sinha  Female  21.0         8                81.2
# 85       DS086    Simran Verma    Male  19.0         8                89.0
# 75       DS076  Saurabh Mishra    Male  18.0         8                81.8
# 167      DS168     Sneha Kumar    Male  20.0         8                82.5
# 162      DS163      Isha Verma    Male  23.0         8                60.4
#
# ...

# %% [markdown]
# ### Q38. Rank all students based on predicted_score.

# %%
df["predicted_score_rank"] = df["predicted_score"].rank(ascending=False, method="min")
df[["student_name", "predicted_score", "predicted_score_rank"]].sort_values("predicted_score_rank")
# Out:
#       student_name  predicted_score  predicted_score_rank
# 73     Neha Pandey             96.3                   1.0
# 14    Kunal Sharma             95.9                   2.0
# 122  Saurabh Kumar             94.0                   3.0
# 49    Kunal Mishra             93.9                   4.0
# 129    Arjun Singh             93.5                   5.0
# ..             ...              ...                   ...
# 72   Saurabh Sinha             61.2                 196.0
# 167    Sneha Kumar             61.1                 197.0
# 162     Isha Verma             60.8                 198.0
# 145     Aman Singh             60.3                 199.0
# 94     Aryan Singh             60.0                 200.0
#
# [200 rows x 3 columns]

# %% [markdown]
# ### Q39. Display the top 10 students based on engagement_score.

# %%
df.sort_values(by="engagement_score", ascending=False).head(10)
# Out:
#     student_id   student_name  gender   age  semester  attendance_percent  \
# 65       DS066   Kavya Pandey    Male  23.0         5                98.3
# 126      DS127   Kavya Sharma  Female  21.0         3                77.9
# 107      DS108   Vivaan Singh  Female  23.0         3                94.0
# 112      DS113  Saurabh Verma  Female  23.0         4                73.0
# 15       DS016    Kavya Singh  Female  19.0         8                75.2
# 98       DS099   Aditya Yadav    Male  18.0         6                62.8
# 158      DS159    Pooja Yadav    Male  18.0         7                91.3
# 35       DS036     Neha Kumar  Female  22.0         8                81.3
# 21       DS022   Ananya Gupta  Female  18.0         7                67.2
# 16       DS017     Isha Yadav  Female  23.0         8                81.5
#
#      study_hours_per_day  assignment_average  quiz_average  mid_sem_score  \
# 65                   5.7                52.8          64.4          56.10
# ...

# %% [markdown]
# ### Q40. Find the student with the highest online_activity_count.

# %%
df.loc[df["online_activity_count"].idxmax()]
# Out:
# student_id                                       DS034
# student_name                              Aditya Singh
# gender                                          Female
# age                                               21.0
# semester                                             8
# attendance_percent                                57.5
# study_hours_per_day                                NaN
# assignment_average                                79.0
# quiz_average                                      83.5
# mid_sem_score                                      7.8
# previous_cgpa                                      NaN
# lab_hours_per_week                                 7.7
# online_activity_count                              200
# projects_completed                                   3
# python_skill_level                            Beginner
# mathematics_skill                                 High
# engagement_score                                  43.2
# ...

# %% [markdown]
# ## E. GroupBy and Aggregation

# %% [markdown]
# ### Q41. Calculate the average predicted_score for each semester.

# %%
df.groupby("semester")["predicted_score"].mean().sort_index()
# Out:
# semester
# 3    77.084615
# 4    78.380000
# 5    79.244737
# 6    77.290909
# 7    77.473529
# 8    77.491176
# Name: predicted_score, dtype: float64

# %% [markdown]
# ### Q42. Calculate the average attendance_percent for each semester.

# %%
df.groupby("semester")["attendance_percent"].mean().sort_index()
# Out:
# semester
# 3    79.284615
# 4    75.508571
# 5    73.623684
# 6    79.024242
# 7    78.608824
# 8    79.679412
# Name: attendance_percent, dtype: float64

# %% [markdown]
# ### Q43. Find the average study_hours_per_day for each gender.

# %%
df.groupby("gender")["study_hours_per_day"].mean()
# Out:
# gender
# Female    3.361333
# Male      3.421250
# Name: study_hours_per_day, dtype: float64

# %% [markdown]
# ### Q44. Count the number of students in each grade.

# %%
df["grade"].value_counts()
# Out:
# grade
# B    86
# C    65
# A    41
# D     8
# Name: count, dtype: int64

# %% [markdown]
# ### Q45. Count the number of students in each risk_level.

# %%
df["risk_level"].value_counts()
# Out:
# risk_level
# Low       111
# Medium     52
# High       37
# Name: count, dtype: int64

# %% [markdown]
# ### Q46. Calculate the average predicted_score for each python_skill_level.

# %%
df.groupby("python_skill_level")["predicted_score"].mean()
# Out:
# python_skill_level
# Advanced        78.751220
# Beginner        77.455385
# Intermediate    77.817021
# Name: predicted_score, dtype: float64

# %% [markdown]
# ### Q47. Calculate the average previous_cgpa for each mathematics_skill level.

# %%
df.groupby("mathematics_skill")["previous_cgpa"].mean()
# Out:
# mathematics_skill
# High      7.558750
# Low       7.104545
# Medium    7.355405
# Name: previous_cgpa, dtype: float64

# %% [markdown]
# ### Q48. Find the average engagement_score for each semester.

# %%
df.groupby("semester")["engagement_score"].mean().sort_index()
# Out:
# semester
# 3    54.403846
# 4    57.934286
# 5    55.778947
# 6    56.184848
# 7    53.920588
# 8    54.091176
# Name: engagement_score, dtype: float64

# %% [markdown]
# ### Q49. Calculate the maximum and minimum predicted_score for each grade.

# %%
df.groupby("grade")["predicted_score"].agg(["max", "min"])
# Out:
#         max   min
# grade
# A      96.3  85.0
# B      84.9  75.1
# C      74.8  65.0
# D      64.5  60.0

# %% [markdown]
# ### Q50. Create a grouped summary by semester containing average attendance, average study hours, average predicted score, and number of students.

# %%
semester_summary = df.groupby("semester").agg(
    average_attendance=("attendance_percent", "mean"),
    average_study_hours=("study_hours_per_day", "mean"),
    average_predicted_score=("predicted_score", "mean"),
    number_of_students=("student_id", "count")
).reset_index()

semester_summary
# Out:
#    semester  average_attendance  average_study_hours  average_predicted_score  \
# 0         3           79.284615             2.810000                77.084615
# 1         4           75.508571             3.696296                78.380000
# 2         5           73.623684             3.630000                79.244737
# 3         6           79.024242             3.644000                77.290909
# 4         7           78.608824             3.322222                77.473529
# 5         8           79.679412             3.080769                77.491176
#
#    number_of_students
# 0                  26
# 1                  35
# 2                  38
# 3                  33
# 4                  34
# 5                  34

# %% [markdown]
# ## Assignment Complete
#
# All 50 questions are included above in Google Colab-ready format.
#
# **Tip:** Run the notebook from top to bottom after uploading `students.csv`.
